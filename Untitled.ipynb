# %%
# %matplotlib inline

# %%
# %run plotting.py

# %%
trans_length_plot('trans-length.nc')

# %%
grid_plot('itemsize-grid-small.nc', 'grid-small.png')
# Out:
# Num transactions: 1 of 10
# Basket index: 1 of 1
# Num transactions: 2 of 10
# Basket index: 1 of 1
# Num transactions: 3 of 10
# Basket index: 1 of 1
# Num transactions: 4 of 10
# Basket index: 1 of 1
# Num transactions: 5 of 10
# Basket index: 1 of 1
# Num transactions: 6 of 10
# Basket index: 1 of 1
# Num transactions: 7 of 10
# Basket index: 1 of 1
# Num transactions: 8 of 10
# Basket index: 1 of 1
# Num transactions: 9 of 10
# Basket index: 1 of 1
# Num transactions: 10 of 10
# Basket index: 1 of 1
